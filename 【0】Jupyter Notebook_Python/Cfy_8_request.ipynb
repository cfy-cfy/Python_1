# %%
#【1】request模块:get、head、post、content、text、json、status_code/encoding/apparent_encoding、decode
import requests
'''______________________ requests.get  ______________________'''
# r = requests.get("http://www.baidu.com")      # 获得全部文本信息 uRL对应的页面内容
# print(r.headers)                              # 头部信息
# print(r.text) 
'''___________________ requests.head  _________________________'''
# r2 = requests.head("http://www.baidu.com")       # just head information
# print(r.headers)                                 # head information
'''________________________ requests.post  ____________________'''
# payload = {"key1":"value1","key2":"value2"}
# r3 = requests.post("http://www.baidu.com",data=payload)
# print(r3.text)
'''_________requests.get/ text/status_code/encoding/apparent_encoding/content.decode_____________'''
# r = requests.get("http://www.baidu.com")
# print(r.status_code)           # HTTP请求的返回状态，200表示连接成功。404表示失败
# print(r.text)                  # HTTP响应内容的字符串形式，即，uRL对应的页面内容。
# print(type(r.text))
# print(r.encoding)              # 从HTTP header中猜测的响应内容编码方式
# print(r.apparent_encoding)     # 内容中分析出的响应内容编码方式
# print(r.content.decode(r.encoding))               # 响应内容的二进制形式 （处理图片，视频等使用）
# r.encoding = r.apparent_encoding # 转化编码   r.apparent_encoding  根据它的结果转码
# print(r.text)
'''_______________requests.get /json_____________________________'''
# r = requests.get('http://httpbin.org/get')
# print(type(r.text))
# print(r.json())
# print(type(r.json()))
'''__________________ requests.get / content __________________________'''
# response = requests.get('https://github.com/favicon.ico')
# # print(response.text)    # 由于图片是二进制数据，所以前者在打印是转化为str类型，也就是图片直接转化为字符串，这理所当然会出现乱码。
# # print(response.content) # 结果前带了一个b，这代表是bytes类型的数据
# with open('C:\\Users\\hp\\Desktop\\sfavicon.ico','wb')as f:
#     f.write(response.content)

# %%
#【1】request模块:request/session 获取 response cookie + 将cookie 转为字典 utils.dict_from_cookiejar
import requests
from fake_useragent import UserAgent
url="https://www.baidu.com"
ua = UserAgent(verify_ssl=False)
headers = {'User-Agent': ua.random}
'''_______________________ 响应头：headers + 请求头：request.headers _______________________'''
# response=requests.get(url=url,headers=headers)
# print(response.headers)                # 响应头
# print(response.request.headers)        # 请求头
'''==================================================='''
# import requests
# res = requests.get('http://match.yuanrenxue.com/match/13')
# print(res.text)
# print('——————————————————')
# print(res.headers)
# print('——————————————————')
# print(res.cookies)
# print('——————————————————')
# print(res.headers['Set-Cookie'])
'''_______________________ （0）将cookie 转为字典 _____________________'''
# cookie = "anonymid=jk63khrk-y97r4p; _r01_=1; ln_uact=mr_mao_hacker@163.com; ln_hurl=http://hdn.xnimg.cn/photos/hdn421/20180720/1740/main_JAWQ_0aa000000ceb195a.jpg; _ga=GA1.2.273332130.1532825428; depovince=HUN; JSESSIONID=abcE5k0CiAJDc9ESVEcuw; ick_login=026ba348-e4e9-4871-9ce3-5868b95cfdd3; first_login_flag=1; loginfrom=syshome; wp_fold=0; BAIDU_SSP_lcr=https://www.baidu.com/link?url=VRx_HKUd53I5rYWZHvrQ9VVLotqST6-jtaZDlscFYCO&wd=&eqid=e957aec400037928000000065b64fcab; ick=64518f30-9a22-47df-b3c3-4114f185c3c6; t=8fcf47068763c279eea2620b51b7a3311; societyguester=8fcf47068763c279eea2620b51b7a3311; id=967272361; xnsid=fd736c63; jebecookies=3f9a3853-3371-4857-8268-308d663ca146|||||; jebe_key=19041c4e-4d38-4dc1-bfb9-124b81afae61%7C33b1d8f602cf6dd5a9834fe6f2bf97f2%7C1533346094265%7C1%7C1533346099750"
# cookie_dict = {i.split("=")[0]:i.split("=")[-1] for i in cookie.split("; ")}
# print(cookie_dict)
'''________________________ (1)get ________________________'''
# res = requests.get(url=url,headers=headers).cookies      # .cookies 获取到的是一个cookiejar对象
# for item in res:
#     print(item.name)
#     print(item.value)
'''————————————————————————'''
# cookies = requests.utils.dict_from_cookiejar(res)       # 将cookiejar对象转换为一个字典
# print(cookies)  
'''________________________ (2)session ________________________'''
# 通过Session类新建一个会话
# 往下使用requests的地方，直接使用session即可，session就会保存服务器发送过来的cookie信息
# session=requests.Session()
# response=session.get('http://match.yuanrenxue.com/match/13',headers=headers)
# response=session.get('http://erp.aicabathrooms.com:9050/ocean/')
# print(response.cookies)
# print('________________________')
# print(response.content)
# print('________________________')
# print(response.text)

# %%
# （二）调用迅捷PDF接口_替换 https://app.xunjiepdf.com 
import requests
import time

class PDFReplace():
    def __init__(self):
        self.machineid = 'ccc052ee5200088b92342303c4ea9399'
        self.token = ''
        self.guid = ''
        self.keytag = ''
    def produceToken(self):
        url = 'https://app.xunjiepdf.com/api/producetoken'
        headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0',
                'Accept': 'application/json, text/javascript, */*; q=0.01',
                'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
                'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
                'X-Requested-With': 'XMLHttpRequest',
                'Host': 'app.xunjiepdf.com',
                'Origin': 'https://app.xunjiepdf.com',
                'Connection': 'keep-alive',
                'Referer': 'https://app.xunjiepdf.com/pdfreplace/'}
        data = {'machineid':self.machineid}
        res = requests.post(url,headers=headers,data=data)
        res_json = res.json()
        if res_json['code'] == 10000:
            self.token = res_json['token']
            self.guid = res_json['guid']
            print('成功获取token')
            return True
        else:
            return False
    def uploadPDF(self,filepath,textfirst,textafter):
        filename = filepath.split('/')[-1]
        files = {'file': open(filepath,'rb')}
        url = 'https://app.xunjiepdf.com/api/Upload'
        headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0',
                'Accept': '*/*',
                'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
                'Content-Type': 'application/pdf',
                'Origin': 'https://app.xunjiepdf.com',
                'Connection': 'keep-alive',
                'Referer': 'https://app.xunjiepdf.com/pdf2word/',}
        params = (
                ('tasktype', 'pdfreplace'),
                ('phonenumber', ''),
                ('loginkey', ''),
                ('machineid', self.machineid),
                ('token', self.token),
                ('limitsize', '2048'),
                ('pdfname', filename),
                ('queuekey', self.guid),
                ('uploadtime', ''),
                ('filecount', '1'),
                ('fileindex', '1'),
                ('pagerange', 'all'),
                ('picturequality', ''),
                ('outputfileextension', ''),
                ('picturerotate', '0,undefined'),
                ('filesequence', '0,undefined'),
                ('filepwd', ''),
                ('iconsize', ''),
                ('picturetoonepdf', ''),
                ('isshare', '0'),
                ('softname', 'pdfonlineconverter'),
                ('softversion', 'V5.0'),
                ('validpagescount', '20'),
                ('limituse', '1'),
                ('filespwdlist', ''),
                ('fileCountwater', '1'),
                ('languagefrom', ''),
                ('languageto', ''),
                ('cadverchose', ''),
                ('pictureforecolor', ''),
                ('picturebackcolor', ''),
                ('textold', textfirst),
                ('textnew', textafter),
                ('id', 'WU_FILE_0'),
                ('name', filename),
                ('type', 'application/pdf'),
                ('lastModifiedDate', ''),
                ('size', ''),)
        res= requests.post(url, headers=headers,params=params,files=files)
        res_json = res.json()
        if res_json['message'] == '上传成功':
            self.keytag = res_json['keytag']
            print('成功上传PDF')
            return True
        else:
            return False
    def progress(self):
        url = 'https://app.xunjiepdf.com/api/Progress'
        headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0',
                'Accept': 'text/plain, */*; q=0.01',
                'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
                'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
                'X-Requested-With': 'XMLHttpRequest',
                'Host': 'app.xunjiepdf.com',
                'Origin': 'https://app.xunjiepdf.com',
                'Connection': 'keep-alive',
                'Referer': 'https://app.xunjiepdf.com/pdfreplace/',}
        data = {
              'tasktag': self.keytag,
              'phonenumber': '',
              'loginkey': '',
              'limituse': '1'}
        res= requests.post(url,headers=headers,data=data)
        res_json = res.json()
        if res_json['message'] == '处理成功':
            print('PDF处理完成')
            return True
        else:
            print('PDF正在处理')
            return False
        
    def downloadPDF(self,output):
        url = 'https://app.xunjiepdf.com/download/fileid/%s'%self.keytag
        res = requests.get(url)
        with open(output,'wb') as f:
            f.write(res.content)
            print('PDF下载成功("%s")'%output)
            
    def replacePDF(self,filepath,outpath):
        textfirst=input('请输入需要替换的内容：')
        textafter=input('请输入替换后的内容：')
        filename = filepath.split('/')[-1]
        filename = filename.split('.')[0]+'.pdf'
        self.produceToken()
        self.uploadPDF(filepath,textfirst,textafter)
        while True:
            res = self.progress()
            if res == True:
                break
            time.sleep(1)
        self.downloadPDF(outpath+"Replaced"+filename)
        
if __name__ == '__main__' :
    pdfreplace=PDFReplace()
    pdfreplace.replacePDF('11娃哈哈.pdf','')

# %%
# （三）调用迅捷PDF接口将word转为pdf：https://app.xunjiepdf.com
'''https://mp.weixin.qq.com/s/1wqVhYr_CpDSTNE6ZGBGdQ'''
import time
import requests
class PDF2Word():
    def __init__(self):
        self.machineid = 'ccc052ee5200088b92342303c4ea9399'
        self.token = ''
        self.guid = ''
        self.keytag = ''
    
    def produceToken(self):
        url = 'https://app.xunjiepdf.com/api/producetoken'
        headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0',
                'Accept': 'application/json, text/javascript, */*; q=0.01',
                'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
                'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
                'X-Requested-With': 'XMLHttpRequest',
                'Origin': 'https://app.xunjiepdf.com',
                'Connection': 'keep-alive',
                'Referer': 'https://app.xunjiepdf.com/pdf2word/',}
        data = {'machineid':self.machineid}
        res = requests.post(url,headers=headers,data=data)
        res_json = res.json()
        if res_json['code'] == 10000:
            self.token = res_json['token']
            self.guid = res_json['guid']
            print('成功获取token')
            return True
        else:
            return False
    
    def uploadPDF(self,filepath):
        filename = filepath.split('/')[-1]
        files = {'file': open(filepath,'rb')}
        url = 'https://app.xunjiepdf.com/api/Upload'
        headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0',
                'Accept': '*/*',
                'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
                'Content-Type': 'application/pdf',
                'Origin': 'https://app.xunjiepdf.com',
                'Connection': 'keep-alive',
                'Referer': 'https://app.xunjiepdf.com/pdf2word/',}
        params = (
                ('tasktype', 'pdf2word'),
                ('phonenumber', ''),
                ('loginkey', ''),
                ('machineid', self.machineid),
                ('token', self.token),
                ('limitsize', '2048'),
                ('pdfname', filename),
                ('queuekey', self.guid),
                ('uploadtime', ''),
                ('filecount', '1'),
                ('fileindex', '1'),
                ('pagerange', 'all'),
                ('picturequality', ''),
                ('outputfileextension', 'docx'),
                ('picturerotate', '0,undefined'),
                ('filesequence', '0,undefined'),
                ('filepwd', ''),
                ('iconsize', ''),
                ('picturetoonepdf', ''),
                ('isshare', '0'),
                ('softname', 'pdfonlineconverter'),
                ('softversion', 'V5.0'),
                ('validpagescount', '20'),
                ('limituse', '1'),
                ('filespwdlist', ''),
                ('fileCountwater', '1'),
                ('languagefrom', ''),
                ('languageto', ''),
                ('cadverchose', ''),
                ('pictureforecolor', ''),
                ('picturebackcolor', ''),
                ('id', 'WU_FILE_0'),
                ('name', filename),
                ('type', 'application/pdf'),
                ('lastModifiedDate', ''),
                ('size', ''),)
        res= requests.post(url, headers=headers,params=params,files=files)
        res_json = res.json()
        if res_json['message'] == '上传成功':
            self.keytag = res_json['keytag']
            print('成功上传PDF')
            return True
        else:
            return False
        
    def progress(self):
        url = 'https://app.xunjiepdf.com/api/Progress'
        headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0',
                'Accept': 'text/plain, */*; q=0.01',
                'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
                'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
                'X-Requested-With': 'XMLHttpRequest',
                'Origin': 'https://app.xunjiepdf.com',
                'Connection': 'keep-alive',
                'Referer': 'https://app.xunjiepdf.com/pdf2word/',}
        data = {
              'tasktag': self.keytag,
              'phonenumber': '',
              'loginkey': '',
              'limituse': '1'}
        res= requests.post(url,headers=headers,data=data)
        res_json = res.json()
        if res_json['message'] == '处理成功':
            print('PDF处理完成')
            return True
        else:
            print('PDF处理中')
            return False
        
    def downloadWord(self,output):
        url = 'https://app.xunjiepdf.com/download/fileid/%s'%self.keytag
        res = requests.get(url)
        with open(output,'wb') as f:
            f.write(res.content)
            print('PDF下载成功("%s")'%output)
            
    def convertPDF(self,filepath,outpath):
        filename = filepath.split('/')[-1]
        filename = filename.split('.')[0]+'.docx'
        self.produceToken()
        self.uploadPDF(filepath)
        while True:
            res = self.progress()
            if res == True:
                break
            time.sleep(1)
        self.downloadWord(outpath+filename)
        
if __name__=='__main__':    
    pdf2word = PDF2Word()
    pdf2word.convertPDF('11娃哈哈.pdf','')
