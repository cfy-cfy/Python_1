# %%
# (一) %s + format 格式化字符串: 
# https://mp.weixin.qq.com/s/YKbWor-BHlnahNHOt3rYDQ
'''______________________%s 与 format()__________________________'''
# a = "%s张飞%s关羽%s刘备%s赵云" % (1,2,3,4)
# display(a)
# b  = "{}张飞{}关羽{}刘备{}赵云".format(1,2,3,4)
# display(b)
'''___________________ 1）format()支持位置格式化填充，%s不支持；_____________________________'''
# --------------------方式一-----------------------
# c = "{3}张飞{1}关羽{2}刘备{0}赵云".format(1,2,3,4)
# display(c)
# --------------------方式二-----------------------
# def my_hobbies(fruit,ball,drink):
#     hobbies = "我喜欢水果{fruit}，我也喜欢球类{ball}，我还喜欢饮料{drink}".format(ball=ball,fruit=fruit,drink=drink)
#     return hobbies
# fruit = "apple"
# ball = "basketball"
# drink = "milk"
# my_hobbies(fruit,ball,drink)
'''___________________ 二、%s+format()填充和对齐_____________________________'''
''' --------------------方式一：%s填充-----------------------'''
# a = "%s" % ("张飞")
# display(a)
# # -------------------- 左填充
# a = '%10s' % ('张飞')
# display(a)
## -------------------- 右填充
# b = '%-10s' % ('张飞')
# display(b)
'''--------------------方式二：fromat()填充-----------------------'''
# c = "{}".format("张飞")
# display(c)
# d = "{:10}".format("张飞")
# display(d)
# # -------------------- 左填充
# a = '{:>10}'.format('张飞')
# display(a)
# # -------------------- 右填充
# b = '{:<10}'.format('张飞')
# display(b)
# #  -------------------- 居中填充
# c = '{:^10}'.format('张飞')
# display(c)
# # -------------------- 使用"特定符号"进行填充；
# a = '{:_<10}'.format('张飞')
# display(a)
# a = '{:@<10}'.format('张飞')
# display(a)
'''___________________ 三、%s+format()截断_____________________________'''
# 注意：只有字符串的长度大于这个阶段长度的时候，才会发生截断。
# 当既有截断长度，又有填充长度的时候一般先进行截断，截断后再进行填充
# -------------------- %s 截断 -----------------------
# a = "%.8s" % ("xishi is beautiful")
# display(a)
# b = "%15.8s" % ("xishi is beautiful")
# display(b)
# -------------------- fromat截断 -----------------------
# a = "{:.8}".format("xishi is beautiful")
# display(a)
# b = "{:.8}".format("abc")
# display(b)
# c= "{:*>15.8}".format("abc")
# display(c)
'''___________________ 四、%s+format()格式化输出中，与数字相关的语法_____________________________'''
'''___________________ %s ___________________ '''
# -------------------------------------------
# a = '%5d' % (3000)
# display(a)
# b = '%d' % ("3000")
# display(b)
# ------------------------------------------- ② 使用%s完成浮点数填充，保留2位有效数字
# a = '%.2f' % (3.1415)
# display(a)
# a = '%5.2f' % (3.1415)
# display(a)
'''___________________ fromat  ___________________ '''
# a = '{}-{}'.format("1","2")
# display(a)
# b = '{}-{}'.format(1,2)
# display(b)
#  使用format()完成整数的填充；
# a = '{:$>5d}'.format(3000)
# display(a)
# b = '{:￥>5d}'.format(3000)
# display(b)
# ------------------------------------------- ② format()格式化输出中，浮点数
# 存在的问题：
# 1)当使用的f的时候，不管你传入的数字有几个小数位，最终都将返回一个六位数的小数，这个问题源自c语言，你也不用管，自己知道就行。
# 2）当使用f的时候，可以传入整数；当使用d的时候，就只能传入整数，而不能传入小数。
# a = '{:f}'.format(3.14159268)
# display(a)
# b = '{:f}'.format(3.141)
# display(b)
# c = '{:f}'.format(312)
# display(c)
# d = '{:d}'.format(12.34)
# display(d)
# ------------------------------------------- 
# b = '{:.2f}'.format(3.1415)
# display(b)
# c = '{:$>5.2f}'.format(3.1415)
# display(c)

# %%
# (二) f-string 格式化字符串: 
'''___________ -string用大括{ }表示被替换字段，其中直接填入替换内容即可___________ '''
# name = "Huang Wei"
# print(f"Hello, my name is {name}")
# price = 95.5
# print(f"He has {price}$")
'''___________  f-string的大括号{ }可以填入表达式或调用函数 ___________ '''
# print(f"They have {2+5*2} apples")
# name = "Huang Wei"
# print(f"my name is {name.lower()}")
# import math
# print(f"Π的值为{math.pi}")
'''___________ f-string中使用lambda匿名函数：可以做复杂的数值计算 ___________ '''
# aa = 123.456
# print(f"{(lambda x:x*5-2)(aa):.2f}")
# bb = 8
# cc = 2
# print(f"{(lambda x,y:x+y)(bb,cc)}")
'''___________ {}内使用的引号不能和大括号外的引号定界符引号冲突___________ '''
# print(f'I am {"Huang Wei"}')
# print(f'''I am {'Huang Wei'}''')
# print(f"""I am {'Huang Wei'}""")
# print(f"""I am {"Huang Wei"}""")
'''___________ 大括号外的引号还可以使用\转义，但大括号内不能使用\转义。___________ '''
# print(f"he\'ll go to {'shang hai'}")
# print(f"""he introduces himself {"I'm Tom"}""")
# print(f"""he introduces himself {"I\'m Tom"}""")  # 语法错误
'''___________ f-string大括号外如果需要显示大括号，
则应输入连续两个大括号{{ }}；大括号内需要引号，使用引号即可。___________ '''
# print(f"{{5}}{'apples'}")
'''___________ 默认使用空格填充___________ '''
# name = "Huang Wei"
# print(f"{name:>20}")
# print(f"{name:<20}")
# print(f"{name:^20}")
# ————————————————————————
# name = "Huang Wei"
# print(f"{name:_>20}")
# print(f"{name:_<20}")
# print(f"{name:_^20}")
'''___________ f-string数字符号相关格式描述符：仅针对数值有效 ___________ '''
# a = 12
# b = -25
# print(f"{a:+}")
# print(f"{b:+}")
# print(f"{a:-}")
# print(f"{b:-}")
# print(f"{a: }")
# print(f"{b: }")
'''___________ f-string宽度与精度相关格式描述符：保留小数点位数 ___________ '''
# a = 123.456
# # 只指定width
# print(f"{a:10}")
# # 只指定0width
# print(f"{a:010}")
# ————————————————————————
# a = 123.456
# # 使用width.precision
# print(f"{a:8.1f}")
# print(f"{a:8.2f}")
# print(f"{a:.2f}")
# # 在width后面，直接加f，表示补足小数点后的位数至默认精度6
# print(f"{a:2f}")
'''___________ f-string截断与填充的结合使用 ___________ '''
# a = "Hello"
# # 当发生截断的时候，如果不指定填充符，默认使用空格填充
# print(f"{a:10.3}")
# # 在发生截断的时候，使用指定的填充符
# print(f"{a:_>10.3}")
# print(f"{a:_<10.3}")
'''___________ f-string针对date、datetime和time对象，进行年月日、时分秒等信息提取 ___________ '''
# from datetime import *
# # today()返回本地时间的一个date对象
# a = date.today()
# display(a)
# print(f"{a:%Y-%m-%d}")

# %%
# （三）综合案例——使用%、format、f-string打印九九乘法表
'''_____________ ① %s方式 _____________'''
# for i in range(1,10):
#     for j in range(1,i+1):
#         print("%s*%s=%s" % (j,i,j*i),end=" ")
#     print("\n")
'''_____________ ② format方式 _____________'''
# for i in range(1,10):
#     for j in range(1,i+1):
#         print("{0}*{1}={2}".format(j,i,j*i),end=" ")
#     print("\n")
'''_____________ ③ f-string方式 _____________'''
# for i in range(1,10):
#     for j in range(1,i+1):
#         print(f"{j}*{i}={j*i}",end=" ")
#     print("\n")
