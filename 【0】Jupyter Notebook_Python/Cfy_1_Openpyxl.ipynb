# %%
# 【0】openpyxl模块：https://openpyxl.readthedocs.org/
也可以直接参考黄编写的文档（中文，相对也比较全面）：https://blog.csdn.net/weixin_41261833/article/details/106028038

# %%
# 批量从Excel中提取指定数据
# from openpyxl import load_workbook, Workbook
# import glob

# path = 'C:/Users/xxxxxx'
# new_workbook = Workbook()
# new_sheet = new_workbook.active

# # 用flag变量明确新表是否已经添加了表头，只要添加过一次就无须重复再添加
# flag = 0

# for file in glob.glob(path + '/*.xlsx'):
#     workbook = load_workbook(file)
#     sheet = workbook.active
    
#     buy_mount = sheet['F']
#     row_lst = []
#     for cell in buy_mount:
#         if isinstance(cell.value, int) and cell.value > 50:
#             print(cell.row)
#             row_lst.append(cell.row)
    
#     if not flag:
#         header = sheet[1]
#         header_lst = []
#         for cell in header:
#             header_lst.append(cell.value)
#         new_sheet.append(header_lst)
#         flag = 1
    
#     for row in row_lst:
#         data_lst = []
#         for cell in sheet[row]:
#             data_lst.append(cell.value)
#         new_sheet.append(data_lst)

# new_workbook.save(path + '/' + '符合筛选条件的新表.xlsx')

# %%
#（一）openpyxl_基础练习1：激活工作表、获取重命名工作表名、赋值、获取值+行列数+坐标 loadworkbook
# from openpyxl import *
# wb=load_workbook(r'C:\Users\hp\Desktop\test.xlsx')    #载入已有的工作簿
#ws=wb.active                       #获取当前激活的工作表
# ws=wb['Sheet1']                   #获取指定工作表
# ws=wb.get_sheet_by_name('Sheet1') #获取指定工作表,即将弃用*************************
# ws.sheet_properties.tabColor="205EB2"     #设置指定工作表-标签颜色
# wb.create_sheet(title='WHH',index=3)      #在指定索引位置插入新建工作表
# print(wb.get_sheet_names())       #获得所有工作表名，即将弃用*************************
# print(wb.sheetnames)              #获得所有工作表名
# print(wb.active.title)            #获得当前激活的工作表名
# ws.title='这是新的工作表名'       #重命名工作表名
# wb.remove(sh)                            #删除指定工作表
# del wb['Sheet1']                         #删除指定工作表
# print(ws.max_row)                 #获取指定工作表最大行数
# print(ws.max_column)              #获取指定工作表最大列数
# print(ws.dimensions)              #获取工作表已使用数据域的行列数。结果是 A1:H11
# cell1=ws['A5']                                             #获取指定区域的值、行数、列数和坐标
# print(cell1.value,cell1.row,cell1.column,cell1.coordinate) #结果：刘备 5 1 A5
'''___________________________________获取工作表值____________________________________'''
# print(ws.cell(row=2,column=2).value)      #获取指定工作表-指定单元格的值
# print(wb['Sheet1']['B2'].value)           #获取指定工作表-指定单元格的值
'''___________________________________________________________________________________'''
# for cell in ws[1]:                  #获取指定工作表-指定“单行”的所有值
#     print(cell.value)
# for cell in ws['A']:                #获取指定工作表-指定“单列”的所有值
#     print(cell.value)
# for cell in list(ws.rows)[2]:                #获取指定工作表-指定“单行”的所有值
#     print(cell.value)
# for cell in list(ws.columns)[2]:             #获取指定工作表-指定“单列”的所有值
#     print(cell.value)
# for row in ws.iter_rows(min_row=1,max_row=1):        #获取指定工作表-指定“单行”的所有值
#     for cell in row:
#         print(cell.value)
# for col in ws.iter_rows(min_col=1,max_col=1):        #获取指定工作表-指定“单列”的所有值
#     for cell in col:
#         print(cell.value)
'''___________________________________________________________________________________'''
# for row in ws.rows:                #获取指定工作表-所有“行”的值
#     for cell in row:
#         print(cell.value)
# for col in ws.columns:                       #获取指定工作表-所有“列”的值
#     for cell in col:
#         print(cell.value)
# for row in ws.iter_rows():         #获取指定工作表-所有“行”的值
#     for cell in row:
#         print(cell.value)
# for col in ws.iter_cols():                   #获取指定工作表-所有“列”的值
#     for cell in col:
#         print(cell.value)
'''___________________________________________________________________________________'''
# for row in ws[1:3]:                 #获取指定工作表-指定“多行”的所有值
#     for cell in row:
#         print(cell.value)
# for col in ws['A:C']:               #获取指定工作表-指定“多列”的所有值
#     for cell in col:
#         print(cell.value)
# for row in list(ws.rows)[0:3]:               #获取指定工作表-指定“多行”的所有值
#     for cell in row:
#         print(cell.value)
# for col in  list(ws.columns)[0:3]:           #获取指定工作表-指定“多列”的所有值
#     for cell in col:
#         print(cell.value)
# for row in ws.iter_rows(min_row=1,max_row=3):              #获取指定工作表-指定“多行”的所有值
#     for cell in row:
#         print(cell.value)
# for col in ws.iter_cols(min_col=1,max_col=3):              #获取指定工作表-指定“多列”的所有值
#     for cell in col:
#         print(cell.value)
'''___________________________________________________________________________________'''
# for rc in ws.iter_rows(min_row=1,max_row=3,min_col=1,max_col=3): #获取指定工作表-指定“范围”的所有值
#     for cell in rc:
#         print(cell.value)
# for rc in ws['A1:C3']:            #获取指定工作表-指定“范围”的所有值
#     for cell in rc:
#         print(cell.value)
# for i in range(1, 4):             #获取指定工作表-指定“范围”的所有值
#     for j in range(1, 3):
#         print(ws.cell(row=i, column=j).value)

# wb.save(r'C:\Users\hp\Desktop\test.xlsx')    #保存工作簿

# %%
#（二）openpyxl_基础练习2：设置单元格格式、utils/workbook
# from openpyxl import *
# wb=Workbook()                            #新建工作簿
# wb.active.title='whh'                    #重命名新建工作簿的活动工作表
# wb=load_workbook(r'C:\Users\hp\Desktop\tt123.xlsx') # data_only=True 只返回数字，不返回公式
# ws=wb.active                             #选取当前活动工作表
'''____________________________________________________________________________'''
# for i in range(10):
#     ws["A%d" % (i+1)].value = i + 1              #“赋值”指定工作表-指定单元格
#     ws[f"B{i+1}"].value = i + 1
#     ws.cell(i+1,column=3,value = i + 1)
#     ws.cell(i+1,column=4).value= i + 1
# ws['E1']="=sum(A1:A10)"                   #写入公式到单元格
# ws['E1']="=countif(A1:A10,A1:A10)" 
# print(utils.get_column_letter(2))               # 根据列的数字返回——字母
# print(utils.column_index_from_string('D'))      # 根据字母返回列的——数字
'''_________________________________按行添加数据___________________________________________'''
# data = ['Number', 'data1', 'data2', 'data3']    
# data=[['Number', 'data1', 'data2','data3'],[2, 40, 30,1],[3, 40, 25,2],[4, 50, 30,3]]
# for d in data :
#     ws.append(d)
'''_____________________________设置单元格风格--Style___________________________'''
# font1 =styles.Font(name='等线', size=24, italic=True, color=styles.colors.RED, bold=True)  #设置字体
# ws['A1'].font = font1
# ws['B1'].alignment = styles.Alignment(horizontal='center', vertical='center')  #对齐center、right、left等
# ws.row_dimensions[2].height = 40                #设置行高
# ws.column_dimensions['C'].width = 30            #设置列宽
# ws.merge_cells(start_row=1,end_row=2,start_column=1,end_column=2)  # 合并几个单元格
# ws.merge_cells('C1:D2') 
# ws.unmerge_cells('C1:D2')                                          #取消合并
# wb.save(r'C:\Users\hp\Desktop\tt123.xlsx')      #保存工作簿
# print('ok')

# %%
#（三）openpyxl_基础练习3：在单元格输入公式、插入行列、移动单元格、新建删除复制工作表
# from openpyxl import *
# wb=load_workbook(r'C:\Users\hp\Desktop\tt123.xlsx')
# ws=wb['whh']
# ws.title='syy'                 #重命名工作表
'''_____________________________________插入公式_______________________________________'''
# r=ws.max_row
# print(ws.dimensions)
# ws.cell(row=1,column=4,value='标准身高cm')
# print(utils.FORMULAE)                       # 查看python究竟支持写哪些“excel函数公式”呢？
# for i in range(2,r+1,1):
#     ws['D{}'.format(i)]='=if(right(C{},2)="cm",C{},substitute(C{},"m","")*100&"cm")'.format(i,i,i)
'''_______________________________________插入删除行列_____________________________________'''
# ws.insert_rows(idx=4,amount=2)             #指定位置插入2行
# ws.insert_cols(idx=2,amount=4)             #指定位置插入4列
# ws.delete_rows(idx=4,amount=2)                  #指定位置删除2行
# ws.delete_cols(idx=2,amount=4)                  #指定位置删除4列
'''_______________________________________移动单元格_____________________________________'''
# ws.move_range("A1:C2",rows=3,cols=2)
# ws.move_range("C5:C6",rows=-2,cols=-1)
'''_______________________________________新建删除复制工作表_____________________________________'''
# ws=wb.create_sheet(title='xpp')               #新建工作表
# ws=wb['xpp']                            #删除工作表
# wb.remove(ws)
# wb.remove(wb.get_sheet_by_name('xpp'))  #删除工作表
# wb.copy_worksheet(wb['whh'])                   #复制工作表

# print(wb.get_sheet_names())                    #列出工作表名
# print(wb.sheetnames)                          #列出工作表名
# wb.save(r'C:\Users\hp\Desktop\tt123.xlsx')
# print('ok')

# %%
#（四）openpyxl_基础练习4：冻结窗格、筛选、样式styles、行高列宽、合并单元格
# from openpyxl import *
# wb=load_workbook(r'C:\Users\hp\Desktop\tt123.xlsx')
# ws=wb['syy']
# ws.freeze_panes='B2'                   #冻结窗格
# ws.auto_filter.ref=ws.dimensions       #给所有字段添加筛选器；
# ws.auto_filter.ref="A1"                #第一列添加“筛选器”
'''_____________________________________样式styles_______________________________________'''
# cell=ws['A4'] 
'''Font'''          
# cell.font = styles.Font(name="微软雅黑",size=20,bold=True,italic=True,color="FF0000") 
# f=cell.font
# print(f.name,f.size,f.bold,f.italic,f.color)
'''Alignment'''
# 水平对齐：‘distributed'，‘justify'，‘center'，‘leftfill'，‘centerContinuous'，‘right，‘general'；
# 垂直对齐：‘bottom'，‘distributed'，‘justify'，‘center'，‘top'；
# cell.alignment=styles.Alignment(horizontal="center",vertical="center",text_rotation=45,wrap_text=True)
'''Side、Border'''
"""(style 参数的种类： 'double, 'mediumDashDotDot', 'slantDashDot', 'dashDotDot','dotted','hair',
'mediumDashed, 'dashed', 'dashDot', 'thin', 'mediumDashDot','medium', 'thick')"""
# side1 = styles.Side(style="thin",color="FF0000") 
# side2 = styles.Side(style="thick",color="FFFF0000")
# cell.border=styles.Border(left=side1,right=side1,top=side2,bottom=side2)
'''置填充样式PatternFill、GradientFill'''
# cell.fill=styles.PatternFill(fill_type="solid",fgColor="99ccff")
# cell.fill=styles.GradientFill(stop=("FFFFFF","99ccff","000000"))  #渐变颜色
'''_____________________________________行高列宽_______________________________________'''
# ws.row_dimensions[1].height=50           #指定行——行高
# ws.column_dimensions['C'].width=20       #指定列——列宽
# ws.row_dimensions.height=50                    #所有行——行高
# ws.column_dimensions.width=20                  #所有列——列宽
'''_____________________________________合并单元格_______________________________________'''
# ws.merge_cells(start_row=7,start_column=1,end_row=8,end_column=3)
# ws.merge_cells('C1:D2')
# ws.unmerge_cells(start_row=7,start_column=1,end_row=8,end_column=3)
# ws.unmerge_cells('C1:D2')
'''____________________________________________________________________________'''
# wb.save(r'C:\Users\hp\Desktop\tt123.xlsx')
# print(wb.sheetnames)
