# %%
# 【0】OS 模块：创建文件夹 makedirs 、获取当前工作路径 getcwd、system 函数调用其它程序
import os
'''__________________创建文件夹 makedir + mkdir + path.exists _________________________''' 
# file_path=r"C:\Users\hp\Desktop"
# for i in range(1,13):
#     a="{}月销售数据".format(i)
#     file_name=file_path + "\\"+a
#     os.makedirs(file_name)
# -——————————————————————————— path.exists + mkdir
# file_path=r"C:\Users\hp\Desktop\abc" 
# if not os.path.exists(file_path):  # 创建文件夹之前先判断文件夹是否存在
#     os.mkdir(file_path)
'''____________________获取当前工作路径 getcwd_______________________________'''   
# filepath=os.getcwd()
# # os.makedirs(filepath+"\\"+ "Download_Picture")
# filepath=filepath+"\\"+ "Download_Picture"
# print(filepath)
'''____________________system 函数调用其它程序 wget ______________________________'''   
# version = input('请输入安装包版本:')
# cmd = fr'd:\tools\wget http://mirrors.sohu.com/nginx/nginx-{version}.zip'
# os.system(cmd)
# print('下载完毕')

# %%
# 【0】OS 模块：遍历文件夹: walk + listdir + scandir + rename + path（isfile + basename + expanduser）
import os
'''____________________________ 一、遍历指定文件夹（1） walk ____________________________  '''
# for dirpath, dirnames, filenames in os.walk(r'C:\Users\hp\Desktop\Node.js_runoob'):
#     print(f'打开文件夹{dirpath}')       # 当前文件夹路径 
#     if dirnames:
#         print(dirnames)                 # 包含文件夹名称[列表形式] 
#     if filenames:
#         print(filenames)               # 包含文件名称[列表形式]
#     print('-' * 10)
# ____________________________
# for i in os.walk(r'C:\Users\hp\Desktop\Node.js_runoob'):
#     print(i)
'''____________________________ 一、遍历当前目录文件夹（2）listdir ____________________________  '''
# dic={}
# path=os.getcwd()
# print(path)
# for file in os.listdir(path):
#     dic[file]=os.path.join(path, file)
#     print(file)
#     print(os.path.join(path, file))
#     print("—————")
'''____________________________ 一、遍历当前目录文件夹（3）scandir ____________________________  '''
# path=os.getcwd()
# for file in os.scandir(path): 
#     print(file.name, file.path)
'''____________________________ 二、 目标路径是否是文件 isfile ____________________________  '''
# path = 'xxx'
# print(os.path.isfile(path))
'''____________________________ 三、获取路径中的文件名 basename ____________________________  '''
# file_path = r'C:\Users\hp\Desktop\Node.js_runoob\abcd.js'
# print(os.path.basename(file_path))
# print(file_path.split('\\')[-1])
'''____________________________ 四、获取桌面路径 expanduser ____________________________  '''
# desktop_path = os.path.join(os.path.expanduser("~"), 'Desktop')
# print(desktop_path)
'''____________________________ 五、重命名文件/文件夹 rename____________________________  '''
# os.rename('practice.txt', 'practice_rename.txt')  # 重命名文件
# os.rename('文件夹1', '文件夹2')        # 重命名文件夹

# %%
# 【0】OS 模块：打开一个程序
import os
# os.system('notepad')  #打开记事本
# os.system('start notepad')#打开记事本

# %%
# 【0】pathlib 模块 + os模块 + glob模块 + zipfile模块 + open（）：十大文件骚操作
import os
import pathlib
'''____________________ 1. 显示当前目录 ____________________'''
print("当前工作目录:", os.getcwd())
print("当前工作目录:", pathlib.Path.cwd())

'''____________________ 2. 建立一个新目录 ____________________'''
os.mkdir("test_folder")
print("目录是否存在:", os.path.exists("test_folder"))

os.mkdir('/Users/ycui1/PycharmProjects/tmp_folder')
print("目录是否存在:", os.path.exists('/Users/ycui1/PycharmProjects/tmp_folder'))

os.makedirs('tmp_level0/tmp_level1')
print("目录是否存在:", os.path.exists("tmp_level0/tmp_level1"))

# 遇到问题“无法创建已经存在的新目录”。可将exist_ok参设置为True来处理此问题（默认值False值将阻止创建目录）
pathlib.Path("test_folder").mkdir(parents=True, exist_ok=True)
pathlib.Path("test_folder").mkdir(parents=True, exist_ok=False)

'''____________________ 3. 删除目录和文件 ____________________'''
print(f"* 删除文件前 {os.path.isfile('tmp.txt')}")
os.remove('tmp.txt')
print(f"* 删除文件后 {os.path.exists('tmp.txt')}")

print(f"* 删除文件夹前 {os.path.isdir('tmp_folder')}")
os.rmdir('tmp_folder')
... print(f"* 删除文件夹后 {os.path.exists('tmp_folder')}")

# 如果使用pathlib模块,可以使用unlink()方法，而删除目录可以使用rmdir()方法。
'''____________________ 4. 获取文件列表 ____________________'''
txt_files = list(pathlib.Path('.').glob("*.txt"))
print("Txt files:", txt_files)

from glob import glob
files = list(glob('h*'))
print("以h开头的文件:", files)

'''____________________ 5. 移动和复制文件 ____________________'''
target_folder = Path("目标文件")
target_folder.mkdir(parents=True,exist_ok=True)
source_folder = Path('.')

txt_files = source_folder.glob('*.txt')
for txt_file in txt_files:
    filename = txt_file.name
    target_path = target_folder.joinpath(filename)
    print(f"** 移动文件 {filename}")
    print("目标文件存在:", target_path.exists())
    txt_file.rename(target_path)
    print("目标文件存在:", target_path.exists(), '\n')
# ——————————————————————————————复制
import shutil
source_file = "target_folder/hello.txt"
target_file = "hello2.txt"
target_file_path = Path(target_file)
print("* 复制前，文件存在:", target_file_path.exists())
shutil.copy(source_file, target_file)
print("* 复制后，文件存在:", target_file_path.exists())
'''____________________ 6. 检查目录/文件 ____________________'''
# os 模块中 exists() 用法
os.path.exists('path_to_check')

# pathlib 模块中 exists() 用法
Path('directory_path').exists()

# 检查路径是否是目录
os.path.isdir('需要检查的路径')
Path('需要检查的路径').is_dir()

# 检查路径是否是文件
os.path.isfile('需要检查的路径')
Path('需要检查的路径').is_file()
'''____________________ 7. 获取文件信息如：前缀、后缀、名称等 ____________________'''
for py_file in Path().glob('c*.py'):
    print('Name with extension:', py_file.name) # 带后缀
    print('Name only:', py_file.stem)           # 不想带后缀

file_path = Path('closures.py')
print("文件后缀:", file_path.suffix)            # 后缀

# 路径 path 对象
current_file_path = Path('iterable_usages.py')
file_stat = current_file_path.stat()

# 获取文件大小:
print("文件大小（Bytes）:", file_stat.st_size)

# 获取最近访问时间
print("最近访问时间:", file_stat.st_atime)

# 获取最近修改时间
print("最近修改时间:", file_stat.st_mtime)
'''____________________ 8. 读取文件 ____________________'''
# 读取所有的文本
with open("hello2.txt", 'r') as file:
    print(file.read())
    
# 逐行的读取
with open("hello2.txt", 'r') as file:
    for i, line in enumerate(file, 1):
        print(f"* 读取行 #{i}: {line}") 
'''____________________ 9. 写入文件 ____________________'''    
# 向文件中写入新数据
with open("hello3.txt", 'w') as file:
    text_to_write = "Hello Files From Writing"
    file.write(text_to_write)

# 增加一些数据
with open("hello3.txt", 'a') as file:
    text_to_write = "\nHello Files From Appending"
    file.write(text_to_write)
    
# 检查文件数据是否正确
with open("hello3.txt") as file:
    print(file.read())
'''____________________ 10. 压缩和解压缩文件 ____________________'''   
from zipfile import ZipFile

# 创建压缩文件
with ZipFile('text_files.zip', 'w') as file:
    for txt_file in Path().glob('*.txt'):
        print(f"*添加文件: {txt_file.name} 到压缩文件")
        file.write(txt_file)
        
# 解压缩文件
with ZipFile('text_files.zip') as zip_file:
    zip_file.printdir()
    zip_file.extractall()

# %%
# 【1】shutil + glob 模块： move
import shutil 
import glob
'''____________________________ 1、移动文件/文件夹 shutil.move____________________________  '''
# shutil.move(r'.\practice.txt', r'.\文件夹1/') 
# shutil.move(r'.\practice.txt', r'.\文件夹1/new.txt') # 将目标文件移动到目标文件夹里的同时，能够对其进行重命名
'''____________________________ 1、移动文件/文件夹 shutil.move____________________________  '''
'''glob 最重要的功能就是搜索获取同一级或者各子级下符合条件的文件（绝对路径），非常适合写批处理的代码。
glob.glob() 是一个非常重要的方法，能够获取给定路径下文件的绝对路径，并且接受「通配符」搜索，大大拓宽了灵活程度，
* 表示任意字符长度，**/* 的使用表示用通配符指代给定路径下的任何一层，recursive 参数允许遍历搜索。
'''
for file in glob.glob('**/*', recursive=True): 
    print(file)

# %%
# 【2】sys 模块：

# %%
# （二。0）time 时间模块简介：
'''
time.altzone	返回格林威治西部的夏令时地区的偏移秒数；如果该地区在格林威治东部会返回负值（如西欧，包括英国）；对夏令时启用地区才能使用。
* time.asctime([t])	接受时间元组并返回一个可读的形式为"Tue Dec 11 18:07:14 2015"（2015年12月11日 周二 18时07分14秒）的 24 个字符的字符串。
* time.clock()	用以浮点数计算的秒数返回当前的 CPU 时间。用来衡量不同程序的耗时，比 time.time() 更有用。
                Python 3.3 以后不被推荐，由于该方法依赖操作系统，建议使用 perf_counter() 或 process_time() 代替（一个返回系统运行时间，一个返回进程运行时间，请按照实际需求选择）	
* time.time() 	 是统计的wall time(即墙上时钟)，也就是系统时钟的时间戳（1970纪元后经过的浮点秒数）。所以两次调用的时间差即为系统经过的总时间。
* time.time_ns()  精确到纳秒
* time.ctime([secs]) 	作用相当于 asctime(localtime(secs))，未给参数相当于 asctime()
time.gmtime([secs])	接收时间辍（1970 纪元年后经过的浮点秒数）并返回格林威治天文时间下的时间元组 t（注：t.tm_isdst 始终为 0）
time.daylight	如果夏令时被定义，则该值为非零。
* time.localtime([secs])	接收时间辍（1970 纪元年后经过的浮点秒数）并返回当地时间下的时间元组 t（t.tm_isdst 可取 0 或 1，取决于当地当时是不是夏令时）
* time.mktime(t)	接受时间元组并返回时间辍（1970纪元后经过的浮点秒数）
* time.perf_counter()	返回计时器的精准时间（系统的运行时间），包含整个系统的睡眠时间。由于返回值的基准点是未定义的，所以，只有连续调用的结果之间的差才是有效的。
* time.perf_counter_ns() 精确到纳秒
* time.process_time() 	返回当前进程执行 CPU 的时间总和，不包含睡眠时间。由于返回值的基准点是未定义的，所以，只有连续调用的结果之间的差才是有效的。
* time.process_time_ns() 精确到纳秒
* time.sleep(secs)	推迟调用线程的运行，secs 的单位是秒。
* time.strptime(string[, format]) 将时间字符串转为元组
* time.strftime(format[, t]) 	把一个代表时间的元组或者 struct_time（如由 time.localtime() 和 time.gmtime() 返回）转化为格式化的时间字符串。如果 t 未指定，将传入 time.localtime()。如果元组中任何一个元素越界，将会抛出 ValueError 异常。
        参数:format -- 格式字符串； t -- 可选的参数t是一个struct_time对象。
        返回值：返回以可读字符串表示的当地时间。
        说明：
        # %y 两位数的年份表示（00-99）
        # %Y 四位数的年份表示（000-9999）
        # %m 月份（01-12）
        # %d 月内中的一天（0-31）
        # %H 24小时制小时数（0-23）
        # %I 12小时制小时数（01-12）
        # %M 分钟数（00=59）
        # %S 秒（00-59）
        # %a 本地简化星期名称
        # %A 本地完整星期名称
        # %b 本地简化的月份名称
        # %B 本地完整的月份名称
        # %c 本地相应的日期表示和时间表示
        # %j 年内的一天（001-366）
        # %p 本地A.M.或P.M.的等价符
        # %U 一年中的星期数（00-53）星期天为星期的开始
        # %w 星期（0-6），星期天为星期的开始
        # %W 一年中的星期数（00-53）星期一为星期的开始
        # %x 本地相应的日期表示
        # %X 本地相应的时间表示
        # %Z 当前时区的名称
        %% %号本身
'''

# %%
# （二。1）time + datetime时间模块：sleep +ctime +asctime +localtime +mktime +clock +time +perf_counter +strftime 
import time
from datetime import datetime
'''______________  sleep + ctime + asctime + localtime + mktime + strftime + strptime  _____________'''
# print("Start : %s" % time.ctime())    # 获得当前时间字符串 Wed Dec 16 22:24:40 2020
# time.sleep(2)
# print("End : %s" % time.asctime())    # 获得当前时间字符串 Wed Dec 16 22:24:42 2020

# print(time.localtime())               # 返回当前时间元组 time.struct_time(tm_year=2020, tm_mon=12, tm_mday=13, tm_hour=23, tm_min=11, tm_sec=21, tm_wday=6, tm_yday=348, tm_isdst=0)
# print(time.localtime(1608128682.0))   # 返回指定的时间元组 time.struct_time(tm_year=2020, tm_mon=12, tm_mday=16, tm_hour=22, tm_min=24, tm_sec=42, tm_wday=2, tm_yday=351, tm_isdst=0)
# print(time.asctime(time.localtime())) # 将元组转为时间字符串 Sun Dec 13 23:11:21 2020
# print(time.mktime(time.localtime()))  # 将元组转为秒数 1608128682.0
# print(time.ctime(1608128682.0))       # 将浮点数转为时间字符串 Wed Dec 16 22:24:42 2020
# print(time.strftime("%Y:%m:%d",time.localtime()))  # 将元组转为指定格式时间字符串 2020:12:16
# print(time.strftime("%Y/%m/%d",time.localtime()))  # 将元组转为指定格式时间字符串 2020/12/16
# print(datetime.now().strftime("%Y-%m-%d"))         # 将当前日期和时间2020-12-17 21:34:06.179448 转为指定格式 2020-12-17
# print(time.strptime("Wed Dec 16 22:24:42 2020"))   # 将字符串转为元组  time.struct_time(tm_year=2020, tm_mon=12, tm_mday=16, tm_hour=22, tm_min=24, tm_sec=42, tm_wday=2, tm_yday=351, tm_isdst=-1)
# print(time.strptime("30 11 2020", "%d %m %Y"))     # 将字符串转为元组
'''_____________________ clock + time + perf_counter 程序运行几计时 ________________________________________'''
# def procedure():
#     time.sleep(2.5)
# t0 = time.clock()           # A 是统计cpu时间 的工具，这在统计某一程序或函数的执行速度最为合适
# procedure()
# print(round(time.clock() - t0,2), "A seconds process time")
# t0 = time.time()           # B 是统计的wall time(即墙上时钟)，也就是系统时钟的时间戳（1970纪元后经过的浮点秒数）。
# procedure()
# print(round(time.time() - t0,2), "B seconds process time")
# t0 = time.perf_counter()   # C
# procedure()
# print(round(time.perf_counter() - t0,2), "C seconds process time")
'''___________strftime 函数接收以时间元组，并返回以可读字符串表示的当地时间，格式由参数 format定 ________'''
# print('我是time()方法：{}'.format(time.time()))
# print('我是perf_counter()方法：{}'.format(time.perf_counter()))
# print('我是process_time()方法：{}'.format(time.process_time()))
# t0 = time.time()
# c0 = time.perf_counter()
# p0 = time.process_time()
# r = 0
# for i in range(1000000):
#     r += i
# time.sleep(2)
# print(r)
# t1 = time.time()
# c1 = time.perf_counter()
# p1 = time.process_time()
# spend1 = t1 - t0
# spend2 = c1 - c0
# spend3 = p1 - p0
# print("time()方法用时：{}s".format(spend1))
# print("perf_counter()用时：{}s".format(spend2))
# print("process_time()用时：{}s".format(spend3))
# print("测试完毕")
'''________________ strftime +datetime.now 函数接收以时间元组，并返回以可读字符串表示的当地时间 ____________'''
# now = datetime.now() 
# year = now.strftime("%Y")
# print("year:", year)

# month = now.strftime("%m")
# print("month:", month)

# day = now.strftime("%d")
# print("day:", day)

# time = now.strftime("%H:%M:%S")
# print("time:", time)

# date_time = now.strftime("%Y-%m-%d, %H:%M:%S")
# print("date and time:",date_time)

'''_____________ strptime() 函数根据指定的格式把一个时间字符串解析为时间元组 _____________'''
# print(time.strptime("30 Nov 2020", "%d %b %Y"))
# print(time.strptime("30 11 2020", "%d %m %Y"))

# %%
# （三）datetime 模块:datetime,now,timestamp,fromtimestamp,utcfromtimestamp,strptime,strftime,timedelta,timezone,replace
from datetime import date,timedelta,timezone
import datetime

t=datetime.datetime.today()
# print(datetime.datetime.today())  # 2020-12-17 22:55:09.810194
# print(datetime.date.today())      # 2020-12-17
# print(t.year) 
# print(t.month) 
# print(t.day) 
# print(t.hour) 
# print(t.minute)
# print(t.second)
# print(datetime.datetime.weekday(t))
'''_______________________ now() 获取当前日期和时间 _______________________'''
# now=datetime.now()
# print(now)         # 2020-12-17 21:34:06.179448
# print(type(now))   # <class 'datetime.datetime'>
# now                # datetime.datetime(2020, 12, 17, 22, 34, 39, 945851)
'''_______________________datetime() 获取指定日期和时间 _______________________
datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
'''
# dt = datetime(2015, 4, 19, 12, 20) # 用指定日期时间创建datetime—— 2015-04-19 12:20:00
# print(dt)
'''_______________________ datetime转换为timestamp _______________________ 
在计算机中，时间实际上是用数字表示的。我们把1970年1月1日 00:00:00 UTC+00:00时区的时刻称为epoch time，
记为0（1970年以前的时间timestamp为负数），当前时间就是相对于epoch time的秒数，称为timestamp。
你可以认为：timestamp = 0 = 1970-1-1 00:00:00 UTC+0:00
对应的北京时间是：timestamp = 0 = 1970-1-1 08:00:00 UTC+8:00
可见timestamp的值与时区毫无关系，因为timestamp一旦确定，其UTC时间就确定了，转换到任意时区的时间也是完全确定的，
这就是为什么计算机存储的当前时间是以timestamp表示的，因为全球各地的计算机在任意时刻的timestamp都是完全相同的（假定时间已校准）。
'''
# dt = datetime(2015, 4, 19, 12, 20) # 用指定日期时间创建datetime——2015-04-19 12:20:00
# print(dt)
# print(dt.timestamp() )             # 把datetime转换为timestamp ——  429417200.0
'''_______________________fromtime()stamp将 timestamp转换为datetime _______________________ '''
# t=1429417200.0
# print(datetime.fromtimestamp(t))    # 本地时间,指当前操作系统设定的时区——2015-04-19 12:20:00
# print(datetime.utcfromtimestamp(t)) # UTC时间——2015-04-19 04:20:00
'''_______________________ timezone + replace 本地时间转换为UTC时间 _______________________ '''
# now = datetime.now()
# print(now)
# tz_utc_8 = timezone(timedelta(hours=8)) # 创建时区UTC+8:00
# dt = now.replace(tzinfo=tz_utc_8)       # 强制设置为UTC+8:00
# print(dt)
'''_______________________strptime()将 str转换为datetime _______________________ '''
# cday = datetime.strptime('2015-6-1 18:19:59', '%Y-%m-%d %H:%M:%S') # 2015-06-01 18:19:59
# print(cday)
'''_______________________strftime()将 datetime转换为str _______________________ '''
# now = datetime.now()
# print(now.strftime('%a, %b %d %H:%M'))          # Thu, Dec 17 21:50
# print(datetime.strftime(now,'%a, %b %d %H:%M'))
'''_______________________ timedelta() datetime加减 _______________________ '''
# now = datetime.now()
# print(now)
# print(now + timedelta(hours=10))
# print(now - timedelta(days=1))
# print(now + timedelta(days=2, hours=12))

# %%
# （四）timeit 时间模块
'''
timeit模块提供了一种简单的方法来计算一小段Python代码，比如一些循环或者正则匹配。 timeit既有命令行界面，
也有可调用界面。 避免了许多用于测量执行时间的常见陷阱。可以用于基准测试/分析目的的代码块。
'''
import timeit
t = timeit.timeit('"-".join(str(n) for n in range(100))', number=10000)
print(t)
